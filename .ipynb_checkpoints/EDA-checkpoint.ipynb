# %%
import pandas as pd

# %%
df = pd.read_csv('politifact_full_dataset.csv')

# %%
df
# Out:
#                                                     url  \
# 0     https://www.politifact.com/factchecks/2025/sep...
# 1     https://www.politifact.com/factchecks/2025/sep...
# 2     https://www.politifact.com/factchecks/2025/sep...
# 3     https://www.politifact.com/factchecks/2025/sep...
# 4     https://www.politifact.com/factchecks/2025/sep...
# ...                                                 ...
# 1494  https://www.politifact.com/factchecks/2024/jul...
# 1495  https://www.politifact.com/factchecks/2024/jul...
# 1496  https://www.politifact.com/factchecks/2024/jun...
# 1497  https://www.politifact.com/factchecks/2024/jun...
# 1498  https://www.politifact.com/factchecks/2024/jun...
#
#                                                   claim  \
# 0     “North Carolina has just approved a law permit...
# 1     Former North Carolina Gov. Roy Cooper “bears d...
# 2     A book on Amazon titled “The Shooting of Charl...
# 3     “Wind and solar energy infrastructure is essen...
# ...

# %%
df.describe()
# Out:
#                                                       url  \
# count                                                1499
# unique                                               1499
# top     https://www.politifact.com/factchecks/2024/jun...
# freq                                                    1
#
#                                                     claim         speaker  \
# count                                                1499            1499
# unique                                               1498             172
# top     Video shows Robert Kennedy Jr. promoting a dia...  Facebook posts
# freq                                                    2             328
#
#                                          desc ruling  \
# count                                    1499   1499
# unique                                   1264      8
# top     stated on January 20, 2025 in a post:  false
# freq                                        5   1039
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   url      1499 non-null   object
#  1   claim    1499 non-null   object
#  2   speaker  1499 non-null   object
#  3   desc     1499 non-null   object
#  4   ruling   1499 non-null   object
#  5   tags     1499 non-null   object
#  6   author   1499 non-null   object
#  7   date     1499 non-null   object
#  8   summary  1477 non-null   object
#  9   article  1499 non-null   object
#  10  sources  1499 non-null   object
# dtypes: object(11)
# memory usage: 128.9+ KB

# %%
df[df['sources'].str.contains(';')]
# Out:
#                                                     url  \
# 0     https://www.politifact.com/factchecks/2025/sep...
# 1     https://www.politifact.com/factchecks/2025/sep...
# 2     https://www.politifact.com/factchecks/2025/sep...
# 3     https://www.politifact.com/factchecks/2025/sep...
# 4     https://www.politifact.com/factchecks/2025/sep...
# ...                                                 ...
# 1494  https://www.politifact.com/factchecks/2024/jul...
# 1495  https://www.politifact.com/factchecks/2024/jul...
# 1496  https://www.politifact.com/factchecks/2024/jun...
# 1497  https://www.politifact.com/factchecks/2024/jun...
# 1498  https://www.politifact.com/factchecks/2024/jun...
#
#                                                   claim  \
# 0     “North Carolina has just approved a law permit...
# 1     Former North Carolina Gov. Roy Cooper “bears d...
# 2     A book on Amazon titled “The Shooting of Charl...
# 3     “Wind and solar energy infrastructure is essen...
# ...

# %%
df.nunique()
# Out:
# url        1499
# claim      1498
# speaker     172
# desc       1264
# ruling        8
# tags       1002
# author       42
# date        387
# summary    1404
# article    1499
# sources    1499
# dtype: int64

# %%
df.groupby('ruling')['url'].count()
# Out:
# ruling
# barely-true      96
# false          1039
# full-flop         4
# half-flip         2
# half-true        56
# mostly-true      40
# pants-fire      238
# true             24
# Name: url, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
print(df['ruling'].value_counts())
df['ruling'].value_counts().plot(kind = 'barh', title = 'Distribution of Rulings')
# Out:
# ruling
# false          1039
# pants-fire      238
# barely-true      96
# half-true        56
# mostly-true      40
# true             24
# full-flop         4
# half-flip         2
# Name: count, dtype: int64
# <Axes: title={'center': 'Distribution of Rulings'}, ylabel='ruling'>

# %%
df['claim_length'] = df['claim'].str.split().apply(len)
print(df['claim_length'].describe())
# Out:
# count    1499.000000
# mean       15.909940
# std         6.509869
# min         3.000000
# 25%        11.000000
# 50%        15.000000
# 75%        19.000000
# max        52.000000
# Name: claim_length, dtype: float64

# %%
df['article_length'] = df['article'].str.split().apply(len)
print(df['article_length'].describe())
# Out:
# count    1499.000000
# mean      576.923282
# std       336.823192
# min       138.000000
# 25%       303.500000
# 50%       476.000000
# 75%       787.500000
# max      2268.000000
# Name: article_length, dtype: float64

# %%
print(df['speaker'].value_counts().head(20))
# Out:
# speaker
# Facebook posts           328
# Instagram posts          220
# Threads posts            168
# X posts                  136
# Viral image              120
# Donald Trump              87
# Social Media              82
# TikTok posts              43
# Kamala Harris             23
# JD Vance                  18
# Tim Walz                   8
# Eric Hovde                 8
# Joe Biden                  6
# Gavin Newsom               6
# Kari Lake                  6
# Elon Musk                  5
# Robert F. Kennedy Jr.      5
# Byron Donalds              5
# Pete Buttigieg             4
# Tim Sheehy                 4
# Name: count, dtype: int64

# %%
all_tags = ';'.join(df['tags']).split(';')
pd.Series(all_tags).str.strip().value_counts().head(20).plot(kind = 'barh', title = 'Top Tags')
# Out:
# <Axes: title={'center': 'Top Tags'}>
